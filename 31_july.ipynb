# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/AI Lab/PriceDataSet.csv')

print(df.to_string())
# Out:
#     weight  price
# 0        1     10
# 1        2     20
# 2        3     25
# 3        4     40
# 4        5     45
# 5        6     75
# 6        7     90
# 7        8    100
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165
#     weight  price
# 0        1     10
# 1        2     20
# 2        3     25
# 3        4     40
# 4        5     45
# 5        6     75
# 6        7     90
# 7        8    100
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
df.head()
# Out:
#    weight  price
# 0       1     10
# 1       2     20
# 2       3     25
# 3       4     40
# 4       5     45

# %%
df.head(8)
# Out:
#    weight  price
# 0       1     10
# 1       2     20
# 2       3     25
# 3       4     40
# 4       5     45
# 5       6     75
# 6       7     90
# 7       8    100

# %%
df.head(5)
# Out:
#    weight  price
# 0       1     10
# 1       2     20
# 2       3     25
# 3       4     40
# 4       5     45

# %%
myvar = pd.DataFrame(df)

print(myvar)
# Out:
#     weight  price
# 0        1     10
# 1        2     20
# 2        3     25
# 3        4     40
# 4        5     45
# 5        6     75
# 6        7     90
# 7        8    100
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
df.corr()
# Out:
#           weight     price
# weight  1.000000  0.989168
# price   0.989168  1.000000

# %%
df.tail()
# Out:
#     weight  price
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   weight  15 non-null     int64
#  1   price   15 non-null     int64
# dtypes: int64(2)
# memory usage: 368.0 bytes

# %%
import matplotlib.pyplot as plt
df.plot(kind = 'scatter', x = 'weight', y = 'price')
plt.xlabel("Weight of potato")
plt.ylabel("Price of potato")
plt.show()

# %%
df.plot(kind = 'line', x = 'weight', y = 'price')

plt.show()

# %%
df.plot(kind="hist",x="weight",y="price")
plt.xlabel("Weight of potato")
plt.ylabel("Price of potato")
plt.show()

# %%
df.plot (kind='bar',x='weight',y='price')
plt.xlabel("Weight of potato")
plt.ylabel("Price of potato")
plt.show()

# %%
df.plot (kind='pie',x='weight',y='price')
plt.xlabel("Weight of potato")
plt.ylabel("Price of potato")
plt.show()

# %%
a=pd.read_csv('/content/drive/MyDrive/AI Lab/PriceDataSet - PriceDataSet.csv')
print (a.to_string())
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3      NaN     40
# 4      5.0     45
# 5      6.0     75
# 6      NaN     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 10     NaN    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
b= a.dropna()
print (b)
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 4      5.0     45
# 5      6.0     75
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
x= a['weight'].mean()
D= a['weight'].fillna(x)
print (D)
print (x)
# Out:
# 0      1.000000
# 1      2.000000
# 2      3.000000
# 3      8.166667
# 4      5.000000
# 5      6.000000
# 6      8.166667
# 7      8.000000
# 8      9.000000
# 9     10.000000
# 10     8.166667
# 11    12.000000
# 12    13.000000
# 13    14.000000
# 14    15.000000
# Name: weight, dtype: float64
# 8.166666666666666

# %%
y=a['weight'].mode(0)[0]
print (y)
# Out:
# nan

# %%
print (a.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# dtype: bool

# %%
m =pd.read_csv('/content/drive/MyDrive/AI Lab/PriceDataSet - PriceDataSet (1).csv')
print (m.to_string())
# Out:
#     weight  price
# 0        1     10
# 1        2     20
# 2        3     25
# 3        4     40
# 4        5     45
# 5        6     75
# 6        7     90
# 7        8    100
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165
# 15      11    130
# 16       3     25
# 17       5     45

# %%
print (a.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16     True
# 17     True
# dtype: bool

# %%
df.describe()
# Out:
#           weight       price
# count  15.000000   15.000000
# mean    8.000000   91.133333
# std     4.472136   52.283385
# min     1.000000   10.000000
# 25%     4.500000   42.500000
# 50%     8.000000  100.000000
# 75%    11.500000  131.000000
# max    15.000000  165.000000

# %%
m.describe()
# Out:
#           weight       price
# count  18.000000   18.000000
# mean    7.722222   87.055556
# std     4.349517   52.008452
# min     1.000000   10.000000
# 25%     4.250000   41.250000
# 50%     7.500000   95.000000
# 75%    11.000000  130.000000
# max    15.000000  165.000000
